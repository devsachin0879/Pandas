# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperatue": [32,45,30],
    "humidity": [80,60,78]
})

# %%
india_weather
# Out:
#        city  temperatue  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78

# %%
us_weather = pd.DataFrame({
    "city":["new york","chicago","orlando"],
    "temperatue": [21,14,35],
    "humidity": [68,65,75]
})

us_weather
# Out:
#        city  temperatue  humidity
# 0  new york          21        68
# 1   chicago          14        65
# 2   orlando          35        75

# %%
df = pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperatue  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78
# 0  new york          21        68
# 1   chicago          14        65
# 2   orlando          35        75

# %%
df = pd.concat([india_weather,us_weather],ignore_index = True)
df
# Out:
#        city  temperatue  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78
# 3  new york          21        68
# 4   chicago          14        65
# 5   orlando          35        75

# %%
df = pd.concat([india_weather,us_weather],keys=["india","us"])
df
# Out:
#              city  temperatue  humidity
# india 0    mumbai          32        80
#       1     delhi          45        60
#       2  banglore          30        78
# us    0  new york          21        68
#       1   chicago          14        65
#       2   orlando          35        75

# %%
df.loc['india']
# Out:
#        city  temperatue  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78

# %%
df.loc['us']
# Out:
#        city  temperatue  humidity
# 0  new york          21        68
# 1   chicago          14        65
# 2   orlando          35        75

# %%
temperature_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperatue": [32,45,30]
}) 
temperature_df
# Out:
#        city  temperatue
# 0    mumbai          32
# 1     delhi          45
# 2  banglore          30

# %%
windspeed_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "windspeed": [7,15,12]
}) 
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai          7
# 1     delhi         15
# 2  banglore         12

# %%
df = pd.concat([temperature_df,windspeed_df])
df
# Out:
#        city  temperatue  windspeed
# 0    mumbai        32.0        NaN
# 1     delhi        45.0        NaN
# 2  banglore        30.0        NaN
# 0    mumbai         NaN        7.0
# 1     delhi         NaN       15.0
# 2  banglore         NaN       12.0

# %%
df = pd.concat([temperature_df,windspeed_df],axis = 1)
df
# Out:
#        city  temperatue      city  windspeed
# 0    mumbai          32    mumbai          7
# 1     delhi          45     delhi         15
# 2  banglore          30  banglore         12

# %%
temperature_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperatue": [32,45,30]
}) 
temperature_df
# Out:
#        city  temperatue
# 0    mumbai          32
# 1     delhi          45
# 2  banglore          30

# %%
windspeed_df = pd.DataFrame({
    "city":["delhi","mumbai"],
    "windspeed": [15,7]
}) 
windspeed_df
# Out:
#      city  windspeed
# 0   delhi         15
# 1  mumbai          7

# %%
df = pd.concat([temperature_df,windspeed_df])
df
# Out:
#        city  temperatue  windspeed
# 0    mumbai        32.0        NaN
# 1     delhi        45.0        NaN
# 2  banglore        30.0        NaN
# 0     delhi         NaN       15.0
# 1    mumbai         NaN        7.0

# %%
temperature_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperatue": [32,45,30]
},index = ['m','d','b']) 
temperature_df
# Out:
#        city  temperatue
# m    mumbai          32
# d     delhi          45
# b  banglore          30

# %%
windspeed_df = pd.DataFrame({
    "city":["delhi","mumbai"],
    "windspeed": [15,7]
},index = ['d','m']) 
windspeed_df
# Out:
#      city  windspeed
# d   delhi         15
# m  mumbai          7

# %%
df = pd.concat([temperature_df,windspeed_df])
df
# Out:
#        city  temperatue  windspeed
# m    mumbai        32.0        NaN
# d     delhi        45.0        NaN
# b  banglore        30.0        NaN
# d     delhi         NaN       15.0
# m    mumbai         NaN        7.0

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperatue    city  windspeed
# m    mumbai          32  mumbai        7.0
# d     delhi          45   delhi       15.0
# b  banglore          30     NaN        NaN

# %%
temperature_df
# Out:
#        city  temperatue
# m    mumbai          32
# d     delhi          45
# b  banglore          30

# %%
s = pd.Series(["Humid","Dry","Rain"],name = "event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
temperature_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperatue": [32,45,30]
}) 
temperature_df
# Out:
#        city  temperatue
# 0    mumbai          32
# 1     delhi          45
# 2  banglore          30

# %%
df = pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperatue  event
# 0    mumbai          32  Humid
# 1     delhi          45    Dry
# 2  banglore          30   Rain
